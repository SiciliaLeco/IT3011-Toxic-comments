# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

path = '/content/drive/My Drive/IT3011 Project/data/train.csv'

df=pd.read_csv(path, sep=',')
df
# Out:
#                       id  ... identity_hate
# 0       0000997932d777bf  ...             0
# 1       000103f0d9cfb60f  ...             0
# 2       000113f07ec002fd  ...             0
# 3       0001b41b1c6bb37e  ...             0
# 4       0001d958c54c6e35  ...             0
# ...                  ...  ...           ...
# 159566  ffe987279560d7ff  ...             0
# 159567  ffea4adeee384e90  ...             0
# 159568  ffee36eab5c267c9  ...             0
# 159569  fff125370e4aaaf3  ...             0
# 159570  fff46fc426af1f9a  ...             0
#
# [159571 rows x 8 columns]

# %%
df['toxic'].value_counts()
# Out:
# 0    144277
# 1     15294
# Name: toxic, dtype: int64

# %%
df[df['toxic']==1 & (df['severe_toxic']==0) & (df['obscene']==0) & (df['threat']==0) & (df['insult']==0) & (df['identity_hate']==0)]
# Out:
#                       id  ... identity_hate
# 12      0005c987bdfc9d4b  ...             0
# 16      0007e25b2121310b  ...             0
# 44      001956c382006abd  ...             0
# 59      002264ea4d5f2887  ...             0
# 151     005f59485fcddeb0  ...             0
# ...                  ...  ...           ...
# 159394  fcf5a6ad5918f164  ...             0
# 159398  fd0129fde97321cb  ...             0
# 159423  fd68ef478b3dfd05  ...             0
# 159448  fdc92e571d39e7e1  ...             0
# 159478  feb5637c531f933d  ...             0
#
# [6597 rows x 8 columns]

# %%
df[df['toxic']==0 & ((df['severe_toxic']==1) | (df['obscene']==1) | (df['threat']==1) | (df['insult']==1) | (df['identity_hate']==1))]
# Out:
#                       id  ... identity_hate
# 0       0000997932d777bf  ...             0
# 1       000103f0d9cfb60f  ...             0
# 2       000113f07ec002fd  ...             0
# 3       0001b41b1c6bb37e  ...             0
# 4       0001d958c54c6e35  ...             0
# ...                  ...  ...           ...
# 159566  ffe987279560d7ff  ...             0
# 159567  ffea4adeee384e90  ...             0
# 159568  ffee36eab5c267c9  ...             0
# 159569  fff125370e4aaaf3  ...             0
# 159570  fff46fc426af1f9a  ...             0
#
# [144277 rows x 8 columns]
